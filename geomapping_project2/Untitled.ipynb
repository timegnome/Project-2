# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from pytrends.request import TrendReq
import us
import datetime
import json
import requests
import gmaps
import os
from scipy import stats


import seaborn as sns
from matplotlib import cm

# %%
csvpath ="countryLockdowndates.csv"
lockdowndf=pd.read_csv(csvpath)
lockdowndf
# Out:
#          Country/Region Province     Date  Type  \
# 0           Afghanistan      NaN  3/24/20  Full
# 1               Albania      NaN   3/8/20  Full
# 2               Algeria      NaN  3/24/20  Full
# 3               Andorra      NaN  3/16/20  Full
# 4                Angola      NaN  3/24/20  Full
# ..                  ...      ...      ...   ...
# 302           Venezuela      NaN  3/16/20  Full
# 303             Vietnam      NaN  3/19/20  Full
# 304  West Bank and Gaza      NaN   3/5/20  Full
# 305              Zambia      NaN      NaN  None
# 306            Zimbabwe      NaN  3/27/20  Full
#
#                                              Reference
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
lockdowndf
# Out:
#          Country/Region Province     Date  Type  \
# 0           Afghanistan      NaN  3/24/20  Full
# 1               Albania      NaN   3/8/20  Full
# 2               Algeria      NaN  3/24/20  Full
# 3               Andorra      NaN  3/16/20  Full
# 4                Angola      NaN  3/24/20  Full
# ..                  ...      ...      ...   ...
# 302           Venezuela      NaN  3/16/20  Full
# 303             Vietnam      NaN  3/19/20  Full
# 304  West Bank and Gaza      NaN   3/5/20  Full
# 305              Zambia      NaN      NaN  None
# 306            Zimbabwe      NaN  3/27/20  Full
#
#                                              Reference
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
lockdowndf['Lat']=""
lockdowndf['Lng']=""

# %%
lockdowndf.dtypes
# Out:
# Country/Region    object
# Province          object
# Date              object
# Type              object
# Reference         object
# Lat               object
# Lng               object
# dtype: object

# %%
lockdowndf.drop(lockdowndf.index[176])
# Out:
#          Country/Region Province     Date  Type  \
# 0           Afghanistan      NaN  3/24/20  Full
# 1               Albania      NaN   3/8/20  Full
# 2               Algeria      NaN  3/24/20  Full
# 3               Andorra      NaN  3/16/20  Full
# 4                Angola      NaN  3/24/20  Full
# ..                  ...      ...      ...   ...
# 302           Venezuela      NaN  3/16/20  Full
# 303             Vietnam      NaN  3/19/20  Full
# 304  West Bank and Gaza      NaN   3/5/20  Full
# 305              Zambia      NaN      NaN  None
# 306            Zimbabwe      NaN  3/27/20  Full
#
#                                              Reference Lat Lng
# 0    https://www.thestatesman.com/world/afghan-govt...
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...
# 2    https://www.garda.com/crisis24/news-alerts/325...
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...
# 4    https://en.wikipedia.org/wiki/2020_coronavirus...
# ...

# %%
params1 = {"key": "AIzaSyBD0e-7oE5jYCTUtZUVOZrMStUEW0K7G9A"}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in lockdowndf.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    
    province = row['Province']
    region = row['Country/Region']
    
    if (pd.notna(province)):
        
        params1['address'] = f"{province}"

    # make request
        cities_lat_lng1 = requests.get(base_url, params=params1)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    # print(cities_lat_lng.url)
    
    # convert to json
        cities_lat_lng1 = cities_lat_lng1.json()


        try:
            lockdowndf.loc[index, "Lat"] = cities_lat_lng1["results"][0]["geometry"]["location"]["lat"]
            lockdowndf.loc[index, "Lng"] = cities_lat_lng1["results"][0]["geometry"]["location"]["lng"]
        
        except:
            params1['address'] = f"{region}"

            # make request
            cities_lat_lng1 = requests.get(base_url, params=params1)

            # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
            # print(cities_lat_lng.url)

            # convert to json
            cities_lat_lng1 = cities_lat_lng1.json()


            try:
                lockdowndf.loc[index, "Lat"] = cities_lat_lng1["results"][0]["geometry"]["location"]["lat"]
                lockdowndf.loc[index, "Lng"] = cities_lat_lng1["results"][0]["geometry"]["location"]["lng"]
            except:
                pass
    
    

    else:
    # update address key value
        params1['address'] = f"{region}"

        # make request
        cities_lat_lng1 = requests.get(base_url, params=params1)

        # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
        # print(cities_lat_lng.url)

        # convert to json
        cities_lat_lng1 = cities_lat_lng1.json()


        try:
            lockdowndf.loc[index, "Lat"] = cities_lat_lng1["results"][0]["geometry"]["location"]["lat"]
            lockdowndf.loc[index, "Lng"] = cities_lat_lng1["results"][0]["geometry"]["location"]["lng"]
        except:
            pass
# # Visualize to confirm lat lng appear

# %%
lockdowndf
# Out:
#          Country/Region Province     Date  Type  \
# 0           Afghanistan      NaN  3/24/20  Full
# 1               Albania      NaN   3/8/20  Full
# 2               Algeria      NaN  3/24/20  Full
# 3               Andorra      NaN  3/16/20  Full
# 4                Angola      NaN  3/24/20  Full
# ..                  ...      ...      ...   ...
# 302           Venezuela      NaN  3/16/20  Full
# 303             Vietnam      NaN  3/19/20  Full
# 304  West Bank and Gaza      NaN   3/5/20  Full
# 305              Zambia      NaN      NaN  None
# 306            Zimbabwe      NaN  3/27/20  Full
#
#                                              Reference      Lat      Lng
# 0    https://www.thestatesman.com/world/afghan-govt...  33.9391    67.71
# 1    https://en.wikipedia.org/wiki/2020_coronavirus...  41.1533  20.1683
# 2    https://www.garda.com/crisis24/news-alerts/325...  28.0339  1.65963
# 3    https://en.wikipedia.org/wiki/2020_coronavirus...  42.5063   1.5218
# ...

# %%
lockdowndf.to_csv("lockdowndates.csv")
